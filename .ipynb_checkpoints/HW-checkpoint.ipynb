# %%
import numpy as np
import pandas as nd

# %%
planes = nd.read_csv("planes.csv")
airlines = nd.read_csv("airlines.csv")
airports = nd.read_csv("airports.csv")
flights = nd.read_csv("flights.csv")
weather = nd.read_csv("weather.csv")
planes.head()
# Out:
#    Unnamed: 0 tailnum    year                     type      manufacturer  \
# 0           1  N10156  2004.0  Fixed wing multi engine           EMBRAER
# 1           2  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 2           3  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 3           4  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 4           5  N10575  2002.0  Fixed wing multi engine           EMBRAER
#
#        model  engines  seats  speed     engine
# 0  EMB-145XR        2     55    NaN  Turbo-fan
# 1   A320-214        2    182    NaN  Turbo-fan
# 2   A320-214        2    182    NaN  Turbo-fan
# 3   A320-214        2    182    NaN  Turbo-fan
# 4  EMB-145LR        2     55    NaN  Turbo-fan

# %%
airlines.head()
# Out:
#    Unnamed: 0 carrier                    name
# 0           1      9E       Endeavor Air Inc.
# 1           2      AA  American Airlines Inc.
# 2           3      AS    Alaska Airlines Inc.
# 3           4      B6         JetBlue Airways
# 4           5      DL    Delta Air Lines Inc.

# %%
airports.head()
# Out:
#    Unnamed: 0  faa                           name        lat        lon   alt  \
# 0           1  04G              Lansdowne Airport  41.130472 -80.619583  1044
# 1           2  06A  Moton Field Municipal Airport  32.460572 -85.680028   264
# 2           3  06C            Schaumburg Regional  41.989341 -88.101243   801
# 3           4  06N                Randall Airport  41.431912 -74.391561   523
# 4           5  09J          Jekyll Island Airport  31.074472 -81.427778    11
#
#    tz dst
# 0  -5   A
# 1  -5   A
# 2  -6   A
# 3  -5   A
# 4  -4   A

# %%
flights.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0           1  2013      1    1     517.0        2.0     830.0       11.0
# 1           2  2013      1    1     533.0        4.0     850.0       20.0
# 2           3  2013      1    1     542.0        2.0     923.0       33.0
# 3           4  2013      1    1     544.0       -1.0    1004.0      -18.0
# 4           5  2013      1    1     554.0       -6.0     812.0      -25.0
#
#   carrier tailnum  flight origin dest  air_time  distance  hour  minute
# 0      UA  N14228    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1      UA  N24211    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2      AA  N619AA    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3      B6  N804JB     725    JFK  BQN     183.0      1576   5.0    44.0
# 4      DL  N668DN     461    LGA  ATL     116.0       762   5.0    54.0

# %%
weather.head()
# Out:
#    Unnamed: 0 origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0           1    EWR  2013    1.0  1.0   0.0  37.04  21.92  53.97     230.0
# 1           2    EWR  2013    1.0  1.0   1.0  37.04  21.92  53.97     230.0
# 2           3    EWR  2013    1.0  1.0   2.0  37.94  21.92  52.09     230.0
# 3           4    EWR  2013    1.0  1.0   3.0  37.94  23.00  54.51     230.0
# 4           5    EWR  2013    1.0  1.0   4.0  37.94  24.08  57.04     240.0
#
#    wind_speed  wind_gust  precip  pressure  visib
# 0    10.35702  11.918651     0.0    1013.9   10.0
# 1    13.80936  15.891535     0.0    1013.0   10.0
# 2    12.65858  14.567241     0.0    1012.6   10.0
# 3    13.80936  15.891535     0.0    1012.7   10.0
# 4    14.96014  17.215830     0.0    1012.8   10.0

# %% [markdown]
# # Q1

# %%
planes['engine'].drop_duplicates()
# Out:
# 0           Turbo-fan
# 51          Turbo-jet
# 424     Reciprocating
# 686           4 Cycle
# 811       Turbo-shaft
# 1045       Turbo-prop
# Name: engine, dtype: object

# %%
planes.head(1)
# Out:
#    Unnamed: 0 tailnum    year                     type manufacturer  \
# 0           1  N10156  2004.0  Fixed wing multi engine      EMBRAER
#
#        model  engines  seats  speed     engine
# 0  EMB-145XR        2     55    NaN  Turbo-fan

# %%
dis_cols = planes.drop_duplicates(subset='type')
dis_cols.loc[:, 'type':'engine'].drop(['speed'], axis=1)
# Out:
#                          type manufacturer      model  engines  seats  \
# 0     Fixed wing multi engine      EMBRAER  EMB-145XR        2     55
# 424  Fixed wing single engine       CESSNA        150        1      2
# 811                Rotorcraft     SIKORSKY      S-76A        2     14
#
#             engine
# 0        Turbo-fan
# 424  Reciprocating
# 811    Turbo-shaft

# %%
planes.count()
# Out:
# Unnamed: 0      3322
# tailnum         3322
# year            3252
# type            3322
# manufacturer    3322
# model           3322
# engines         3322
# seats           3322
# speed             23
# engine          3322
# dtype: int64

# %%
len(planes_data_count)
# Out:
# 3322

# %%
#planes.groupby('engine').agg({'tip': np.mean, 'day': np.size})
planes.groupby(['engine']).agg({'count':np.size})
# Out:
#                count
# engine
# 4 Cycle            2
# Reciprocating     28
# Turbo-fan       2750
# Turbo-jet        535
# Turbo-prop         2
# Turbo-shaft        5

# %%
planes.groupby(['engine','type']).agg({'count':np.size})
# Out:
#                                         count
# engine        type
# 4 Cycle       Fixed wing single engine      2
# Reciprocating Fixed wing multi engine       5
#               Fixed wing single engine     23
# Turbo-fan     Fixed wing multi engine    2750
# Turbo-jet     Fixed wing multi engine     535
# Turbo-prop    Fixed wing multi engine       2
# Turbo-shaft   Rotorcraft                    5

# %%
planes.groupby(['engine','manufacturer']).agg({'year':np.min, 'year': np.max, 'year': np.mean})
# Out:
#                                                     year
# engine        manufacturer
# 4 Cycle       CESSNA                         1975.000000
#               JOHN G HESS                            NaN
# Reciprocating AMERICAN AIRCRAFT INC                  NaN
#               AVIAT AIRCRAFT INC             2007.000000
#               BARKER JACK L                          NaN
#               CESSNA                         1971.142857
#               CIRRUS DESIGN CORP             2007.000000
#               DEHAVILLAND                    1959.000000
#               DOUGLAS                        1956.000000
#               FRIEDEMANN JON                 2007.000000
#               HURLEY JAMES LARRY                     NaN
#               KILDALL GARY                   1985.000000
#               LAMBERT RICHARD                        NaN
#               LEBLANC GLENN T                1985.000000
#               MARZ BARRY                     1993.000000
# ...

# %% [markdown]
# # Q2

# %%
planes['speed'][planes['speed'].notnull()]
# Out:
# 424      90.0
# 427      90.0
# 821     162.0
# 893     167.0
# 1027    105.0
# 1037    232.0
# 1190    107.0
# 1430    112.0
# 1480    127.0
# 1515    162.0
# 1589    126.0
# 1694     95.0
# 1813    432.0
# 1867    202.0
# 1883    108.0
# 2131    432.0
# 2309    105.0
# 2402    432.0
# 2432    432.0
# 2472    432.0
# 2483    432.0
# 2492    432.0
# 2503    432.0
# Name: speed, dtype: float64

# %%
aore2010 = planes[planes['year']>=2010]
aore2010['tailnum']
# Out:
# 88      N127UW
# 89      N128UW
# 215     N150UW
# 216     N151UW
# 218     N152UW
# 221     N153UW
# 223     N154UW
# 228     N155UW
# 230     N156UW
# 233     N157UW
# 418     N198UW
# 421     N199UW
# 435     N205FR
# 437     N206FR
# 441     N207FR
# 443     N208FR
# 445     N20904
# 446     N209FR
# 448     N210FR
# 456     N211FR
# 459     N213FR
# 461     N214FR
# 465     N216FR
# 567     N26906
# 578     N272PQ
# 584     N27477
# 596     N27901
# 600     N279PQ
# 609     N28457
# 610     N28478
#          ...
# 2982    N913JB
# 3148    N943WN
# 3153    N944WN
# 3158    N945WN
# 3162    N946WN
# 3166    N947WN
# 3171    N948WN
# 3175    N949WN
# 3179    N950WN
# 3184    N951WN
# 3187    N952FR
# 3189    N952WN
# 3193    N953FR
# 3195    N953WN
# 3199    N954WN
# 3204    N955WN
# 3210    N956WN
# 3215    N957WN
# 3220    N958WN
# 3225    N959WN
# 3229    N960WN
# 3234    N961WN
# 3237    N962WN
# 3242    N963WN
# 3246    N964WN
# 3251    N965WN
# 3254    N966WN
# ...

# %%
s_bet100and200 = planes[(planes['seats']>=100) & (planes['seats']<=200)]
s_bet100and200['tailnum'].head(20)
# Out:
# 1     N102UW
# 2     N103US
# 3     N104UW
# 5     N105UW
# 6     N107US
# 7     N108UW
# 8     N109UW
# 9     N110UW
# 33    N111US
# 34    N11206
# 35    N112US
# 36    N113UW
# 37    N114UW
# 46    N117UW
# 47    N118US
# 48    N119US
# 51    N12109
# 52    N12114
# 53    N12116
# 55    N12125
# Name: tailnum, dtype: object

# %%
planes[planes['manufacturer'].isin(["BOEING", "AIRBUS", "EMBRAER"])]
# Out:
#       Unnamed: 0 tailnum    year                     type manufacturer  \
# 0              1  N10156  2004.0  Fixed wing multi engine      EMBRAER
# 4              5  N10575  2002.0  Fixed wing multi engine      EMBRAER
# 10            11  N11106  2002.0  Fixed wing multi engine      EMBRAER
# 11            12  N11107  2002.0  Fixed wing multi engine      EMBRAER
# 12            13  N11109  2002.0  Fixed wing multi engine      EMBRAER
# 13            14  N11113  2002.0  Fixed wing multi engine      EMBRAER
# 14            15  N11119  2002.0  Fixed wing multi engine      EMBRAER
# 15            16  N11121  2003.0  Fixed wing multi engine      EMBRAER
# 16            17  N11127  2003.0  Fixed wing multi engine      EMBRAER
# 17            18  N11137  2003.0  Fixed wing multi engine      EMBRAER
# 18            19  N11140  2003.0  Fixed wing multi engine      EMBRAER
# 19            20  N11150  2003.0  Fixed wing multi engine      EMBRAER
# ...

# %%
planes[(planes['manufacturer'].isin(["BOEING", "AIRBUS", "EMBRAER"])) & (planes['seats']>300)]
# Out:
#       Unnamed: 0 tailnum    year                     type manufacturer  \
# 49            50  N1200K  1998.0  Fixed wing multi engine       BOEING
# 50            51  N1201P  1998.0  Fixed wing multi engine       BOEING
# 69            70  N121DE  1987.0  Fixed wing multi engine       BOEING
# 117          118  N136DL  1991.0  Fixed wing multi engine       BOEING
# 122          123  N137DL  1991.0  Fixed wing multi engine       BOEING
# 183          184  N143DA  1998.0  Fixed wing multi engine       BOEING
# 241          242   N1602  1999.0  Fixed wing multi engine       BOEING
# 242          243   N1603  1999.0  Fixed wing multi engine       BOEING
# 243          244  N1604R  1999.0  Fixed wing multi engine       BOEING
# 244          245   N1605  1999.0  Fixed wing multi engine       BOEING
# 245          246  N16065  1999.0  Fixed wing multi engine       BOEING
# 246          247  N1607B  2000.0  Fixed wing multi engine       BOEING
# ...

# %% [markdown]
# # Q3

# %%
planes.groupby(['manufacturer']).agg({'seats':['count']})
# Out:
#                               seats
#                               count
# manufacturer
# AGUSTA SPA                        1
# AIRBUS                          336
# AIRBUS INDUSTRIE                400
# AMERICAN AIRCRAFT INC             2
# AVIAT AIRCRAFT INC                1
# AVIONS MARCEL DASSAULT            1
# BARKER JACK L                     1
# BEECH                             2
# BELL                              2
# BOEING                         1630
# BOMBARDIER INC                  368
# CANADAIR                          9
# CANADAIR LTD                      1
# CESSNA                            9
# CIRRUS DESIGN CORP                1
# DEHAVILLAND                       1
# DOUGLAS                           1
# EMBRAER                         299
# FRIEDEMANN JON                    1
# GULFSTREAM AEROSPACE              2
# HURLEY JAMES LARRY                1
# JOHN G HESS                       1
# KILDALL GARY                      1
# ...

# %%
gdata = planes.groupby(['manufacturer']).agg({'seats':['count']})
gdata[gdata.iloc[:,0]>10]
# Out:
#                               seats
#                               count
# manufacturer
# AIRBUS                          336
# AIRBUS INDUSTRIE                400
# BOEING                         1630
# BOMBARDIER INC                  368
# EMBRAER                         299
# MCDONNELL DOUGLAS               120
# MCDONNELL DOUGLAS AIRCRAFT CO   103
# MCDONNELL DOUGLAS CORPORATION    14

# %%
gadata = planes[planes['seats']>200].groupby(['manufacturer']).agg({'seats':['count']})
gadata[gadata.iloc[:,0]>10]
# Out:
#              seats
#              count
# manufacturer
# AIRBUS          66
# BOEING         225

# %% [markdown]
# # Q4

# %%
ogdata = planes.groupby(['manufacturer']).agg({'seats':['count']})
re_ogdata = ogdata.rename(index=str, columns={"seats": "howmany"})
re_ogdata.sort_values([("howmany","count")])
# Out:
#                               howmany
#                                 count
# manufacturer
# AGUSTA SPA                          1
# DOUGLAS                             1
# DEHAVILLAND                         1
# CIRRUS DESIGN CORP                  1
# HURLEY JAMES LARRY                  1
# CANADAIR LTD                        1
# JOHN G HESS                         1
# KILDALL GARY                        1
# SIKORSKY                            1
# LAMBERT RICHARD                     1
# LEBLANC GLENN T                     1
# BARKER JACK L                       1
# AVIONS MARCEL DASSAULT              1
# AVIAT AIRCRAFT INC                  1
# MARZ BARRY                          1
# PAIR MIKE E                         1
# ROBINSON HELICOPTER CO              1
# LEARJET INC                         1
# FRIEDEMANN JON                      1
# STEWART MACO                        2
# BELL                                2
# BEECH                               2
# ...

# %%
re_ogdata.sort_values([("howmany","count")], ascending = False).head(10)
# Out:
#                               howmany
#                                 count
# manufacturer
# BOEING                           1630
# AIRBUS INDUSTRIE                  400
# BOMBARDIER INC                    368
# AIRBUS                            336
# EMBRAER                           299
# MCDONNELL DOUGLAS                 120
# MCDONNELL DOUGLAS AIRCRAFT CO     103
# MCDONNELL DOUGLAS CORPORATION      14
# CESSNA                              9
# CANADAIR                            9

# %%
planes[planes['year'] >= 2012].sort_values(['year','seats'])
# Out:
#       Unnamed: 0 tailnum    year                     type  \
# 1564        1565  N537JB  2012.0               Rotorcraft
# 815          816  N348JB  2012.0  Fixed wing multi engine
# 825          826  N351JB  2012.0  Fixed wing multi engine
# 837          838  N353JB  2012.0  Fixed wing multi engine
# 2630        2631  N8301J  2012.0  Fixed wing multi engine
# 2631        2632  N8302F  2012.0  Fixed wing multi engine
# 2633        2634  N8305E  2012.0  Fixed wing multi engine
# 2634        2635  N8306H  2012.0  Fixed wing multi engine
# 2635        2636  N8307K  2012.0  Fixed wing multi engine
# 2636        2637  N8308K  2012.0  Fixed wing multi engine
# 2637        2638  N8309C  2012.0  Fixed wing multi engine
# 2642        2643  N8310C  2012.0  Fixed wing multi engine
# 2643        2644  N8311Q  2012.0  Fixed wing multi engine
# 2644        2645  N8312C  2012.0  Fixed wing multi engine
# 2645        2646  N8313F  2012.0  Fixed wing multi engine
# ...

# %%
planes[planes['year'] >= 2012].sort_values(['seats','year'])
# Out:
#       Unnamed: 0 tailnum    year                     type  \
# 1564        1565  N537JB  2012.0               Rotorcraft
# 815          816  N348JB  2012.0  Fixed wing multi engine
# 825          826  N351JB  2012.0  Fixed wing multi engine
# 837          838  N353JB  2012.0  Fixed wing multi engine
# 843          844  N354JB  2013.0  Fixed wing multi engine
# 848          849  N355JB  2013.0  Fixed wing multi engine
# 859          860  N358JB  2013.0  Fixed wing multi engine
# 908          909  N368JB  2013.0  Fixed wing multi engine
# 956          957  N373JB  2013.0  Fixed wing multi engine
# 989          990  N374JB  2013.0  Fixed wing multi engine
# 1003        1004  N375JB  2013.0  Fixed wing multi engine
# 578          579  N272PQ  2013.0  Fixed wing multi engine
# 600          601  N279PQ  2013.0  Fixed wing multi engine
# 628          629  N292PQ  2013.0  Fixed wing multi engine
# 630          631  N293PQ  2013.0  Fixed wing multi engine
# ...

# %% [markdown]
# # Q5

# %%
airports.sample(n=100)
# Out:
#       Unnamed: 0  faa                                  name        lat  \
# 826          827  MGM          Montgomery Regional Airport   32.300639
# 771          772  LPC                        Lompoc Airport  34.665600
# 127          128  APC                   Napa County Airport  38.213194
# 321          322  CXF                      Coldfoot Airport  67.251389
# 18            19  1G3                    Kent State Airport  41.151389
# 838          839  MIV                        Millville Muni  39.367806
# 897          898  MYF                      Montgomery Field  32.475900
# 1022        1023  PHK                       Pahokee Airport  26.789000
# 833          834  MHT           Manchester Regional Airport  42.932556
# 551          552  HFD                     Hartford Brainard  41.736722
# 136          137  ARV                              Lakeland  45.927778
# 1273        1274  TPA                            Tampa Intl  27.975472
# ...

# %%
# sn = int(np.round((5/100)*len(airports)))
# airports.sample(n=sn) 
airports.sample(frac=0.05)
# Out:
#       Unnamed: 0  faa                                           name  \
# 1038        1039  PMB                                   Pembina Muni
# 1259        1260  TLH                               Tallahassee Rgnl
# 391          392  EDW                                    Edwards Afb
# 775          776  LRF                                Little Rock Afb
# 1342        1343  WHP                               Whiteman Airport
# 266          267  CFD                                    Coulter Fld
# 181          182  BHM                                Birmingham Intl
# 239          240  C16                                   Frasca Field
# 1246        1247  TCM                                   Mc Chord Afb
# 687          688  KKA                     Koyuk Alfred Adams Airport
# 148          149  AUW                        Wausau Downtown Airport
# 1039        1040  PMD                      Palmdale Rgnl Usaf Plt 42
# 411          412  ELY                                    Ely Airport
# ...

# %%
airports.head(100)
# Out:
#     Unnamed: 0  faa                                  name        lat  \
# 0            1  04G                     Lansdowne Airport  41.130472
# 1            2  06A         Moton Field Municipal Airport  32.460572
# 2            3  06C                   Schaumburg Regional  41.989341
# 3            4  06N                       Randall Airport  41.431912
# 4            5  09J                 Jekyll Island Airport  31.074472
# 5            6  0A9        Elizabethton Municipal Airport  36.371222
# 6            7  0G6               Williams County Airport  41.467306
# 7            8  0G7         Finger Lakes Regional Airport  42.883565
# 8            9  0P2          Shoestring Aviation Airfield  39.794824
# 9           10  0S9                 Jefferson County Intl  48.053809
# 10          11  0W3                Harford County Airport  39.566838
# 11          12  10C                    Galt Field Airport  42.402889
# 12          13  17G  Port Bucyrus-Crawford County Airport  40.781556
# ...

# %%
airports.tail(100)
# Out:
#       Unnamed: 0  faa                                  name        lat  \
# 1297        1298  UES               Waukesha County Airport  43.041028
# 1298        1299  UGN                         Waukegan Rgnl  42.422161
# 1299        1300  UIN         Quincy Regional Baldwin Field  39.942700
# 1300        1301  UMP     Indianapolis Metropolitan Airport  39.935278
# 1301        1302  UNK                    Unalakleet Airport  63.888333
# 1302        1303  UPP                                 Upolu  20.265256
# 1303        1304  UST                 St. Augustine Airport  29.959167
# 1304        1305  UTM              Tunica Municipal Airport  34.681000
# 1305        1306  UTO                  Indian Mountain Lrrs  65.992794
# 1306        1307  UUK                  Ugnu-Kuparuk Airport  70.330833
# 1307        1308  UUU                         Newport State  41.533056
# 1308        1309  UVA                          Garner Field  29.215429
# ...

# %% [markdown]
# # Q6

# %%
A = airports.loc[1:10, :]
B = airports.loc[6:15, :]

# %%
nd.concat([A,B]).drop_duplicates().reset_index(drop=True)
# Out:
#     Unnamed: 0  faa                                  name        lat  \
# 0            2  06A         Moton Field Municipal Airport  32.460572
# 1            3  06C                   Schaumburg Regional  41.989341
# 2            4  06N                       Randall Airport  41.431912
# 3            5  09J                 Jekyll Island Airport  31.074472
# 4            6  0A9        Elizabethton Municipal Airport  36.371222
# 5            7  0G6               Williams County Airport  41.467306
# 6            8  0G7         Finger Lakes Regional Airport  42.883565
# 7            9  0P2          Shoestring Aviation Airfield  39.794824
# 8           10  0S9                 Jefferson County Intl  48.053809
# 9           11  0W3                Harford County Airport  39.566838
# 10          12  10C                    Galt Field Airport  42.402889
# 11          13  17G  Port Bucyrus-Crawford County Airport  40.781556
# 12          14  19A                Jackson County Airport  34.175864
# ...

# %%
nd.concat([A,B])
# Out:
#     Unnamed: 0  faa                                  name        lat  \
# 1            2  06A         Moton Field Municipal Airport  32.460572
# 2            3  06C                   Schaumburg Regional  41.989341
# 3            4  06N                       Randall Airport  41.431912
# 4            5  09J                 Jekyll Island Airport  31.074472
# 5            6  0A9        Elizabethton Municipal Airport  36.371222
# 6            7  0G6               Williams County Airport  41.467306
# 7            8  0G7         Finger Lakes Regional Airport  42.883565
# 8            9  0P2          Shoestring Aviation Airfield  39.794824
# 9           10  0S9                 Jefferson County Intl  48.053809
# 10          11  0W3                Harford County Airport  39.566838
# 6            7  0G6               Williams County Airport  41.467306
# 7            8  0G7         Finger Lakes Regional Airport  42.883565
# 8            9  0P2          Shoestring Aviation Airfield  39.794824
# ...

# %%
nd.merge(A, B, how='inner')
# Out:
#    Unnamed: 0  faa                           name        lat         lon  \
# 0           7  0G6        Williams County Airport  41.467306  -84.506778
# 1           8  0G7  Finger Lakes Regional Airport  42.883565  -76.781232
# 2           9  0P2   Shoestring Aviation Airfield  39.794824  -76.647191
# 3          10  0S9          Jefferson County Intl  48.053809 -122.810644
# 4          11  0W3         Harford County Airport  39.566838  -76.202403
#
#     alt  tz dst
# 0   730  -5   A
# 1   492  -5   A
# 2  1000  -5   U
# 3   108  -8   A
# 4   409  -5   A

# %%
#nd.concat([A,B]).drop_duplicates(keep=False) # removes only the common colmns
diff = A.loc[A.index.symmetric_difference(B.index)]
diff.dropna()
# Out:
#    Unnamed: 0  faa                            name        lat        lon  \
# 1         2.0  06A   Moton Field Municipal Airport  32.460572 -85.680028
# 2         3.0  06C             Schaumburg Regional  41.989341 -88.101243
# 3         4.0  06N                 Randall Airport  41.431912 -74.391561
# 4         5.0  09J           Jekyll Island Airport  31.074472 -81.427778
# 5         6.0  0A9  Elizabethton Municipal Airport  36.371222 -82.173417
#
#       alt   tz dst
# 1   264.0 -5.0   A
# 2   801.0 -6.0   A
# 3   523.0 -5.0   A
# 4    11.0 -4.0   A
# 5  1593.0 -4.0   A

# %%
diff2 = B.loc[B.index.symmetric_difference(A.index)]
diff2.dropna()
# Out:
#     Unnamed: 0  faa                                  name        lat  \
# 11        12.0  10C                    Galt Field Airport  42.402889
# 12        13.0  17G  Port Bucyrus-Crawford County Airport  40.781556
# 13        14.0  19A                Jackson County Airport  34.175864
# 14        15.0  1A3         Martin Campbell Field Airport  35.015806
# 15        16.0  1B9                   Mansfield Municipal  42.000133
#
#           lon     alt   tz dst
# 11 -88.375111   875.0 -6.0   U
# 12 -82.974806  1003.0 -5.0   A
# 13 -83.561597   951.0 -4.0   U
# 14 -84.346833  1789.0 -4.0   A
# 15 -71.196771   122.0 -5.0   A

# %% [markdown]
# # Q7

# %%
planes.head(1)
# Out:
#    Unnamed: 0 tailnum    year                     type manufacturer  \
# 0           1  N10156  2004.0  Fixed wing multi engine      EMBRAER
#
#        model  engines  seats  speed     engine
# 0  EMB-145XR        2     55    NaN  Turbo-fan

# %%
flights.head(1)
# Out:
#    Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0           1  2013      1    1     517.0        2.0     830.0       11.0
#
#   carrier tailnum  flight origin dest  air_time  distance  hour  minute
# 0      UA  N14228    1545    EWR  IAH     227.0      1400   5.0    17.0

# %%
nd.merge(flights, planes, on='tailnum')
# Out:
#         Unnamed: 0_x  year_x  month  day  dep_time  dep_delay  arr_time  \
# 0                  1    2013      1    1     517.0        2.0     830.0
# 1               6570    2013      1    8    1435.0       -5.0    1717.0
# 2               7111    2013      1    9     717.0       17.0     812.0
# 3               7349    2013      1    9    1143.0       -1.0    1425.0
# 4              10593    2013      1   13     835.0       11.0    1030.0
# 5              13775    2013      1   16    1829.0       59.0    2117.0
# 6              18967    2013      1   22    1902.0       54.0    2214.0
# 7              19417    2013      1   23    1050.0       -6.0    1143.0
# 8              19648    2013      1   23    1533.0        4.0    1641.0
# 9              21046    2013      1   25     724.0        4.0    1000.0
# 10             21464    2013      1   25    1525.0       -4.0    1818.0
# 11             22159    2013      1   26    1235.0        0.0    1558.0
# ...

# %%
airports.head(1)
# Out:
#    Unnamed: 0  faa               name        lat        lon   alt  tz dst
# 0           1  04G  Lansdowne Airport  41.130472 -80.619583  1044  -5   A

# %%
flights.head(1)
# Out:
#    Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0           1  2013      1    1     517.0        2.0     830.0       11.0
#
#   carrier tailnum  flight origin dest  air_time  distance  hour  minute
# 0      UA  N14228    1545    EWR  IAH     227.0      1400   5.0    17.0

# %%
nd.merge(flights, airports, left_on=['flight'], right_on=['Unnamed: 0'])
# Out:
#         Unnamed: 0_x  year  month  day  dep_time  dep_delay  arr_time  \
# 0                  3  2013      1    1     542.0        2.0     923.0
# 1                847  2013      1    2     535.0       -5.0     831.0
# 2                883  2013      1    2     616.0       16.0    1001.0
# 3               1792  2013      1    3     535.0       -5.0     835.0
# 4               2705  2013      1    4     546.0        6.0     851.0
# 5               3620  2013      1    5     537.0       -3.0     831.0
# 6               4338  2013      1    6     534.0       -6.0     855.0
# 7               5170  2013      1    7     531.0       -9.0     827.0
# 8               6102  2013      1    8     531.0       -9.0     826.0
# 9               7004  2013      1    9     533.0       -7.0     823.0
# 10              7906  2013      1   10     531.0       -9.0     832.0
# 11              8838  2013      1   11     530.0      -10.0     812.0
# ...

# %%
weather.head(1)
# Out:
#    Unnamed: 0 origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0           1    EWR  2013    1.0  1.0   0.0  37.04  21.92  53.97     230.0
#
#    wind_speed  wind_gust  precip  pressure  visib
# 0    10.35702  11.918651     0.0    1013.9   10.0

# %%
#nd.merge(flights, airports, on='origin') my computer hung out

# %%
planes.head(1)
# Out:
#    Unnamed: 0 tailnum    year                     type manufacturer  \
# 0           1  N10156  2004.0  Fixed wing multi engine      EMBRAER
#
#        model  engines  seats  speed     engine
# 0  EMB-145XR        2     55    NaN  Turbo-fan

# %%
airports.head(1)
# Out:
#    Unnamed: 0  faa               name        lat        lon   alt  tz dst
# 0           1  04G  Lansdowne Airport  41.130472 -80.619583  1044  -5   A

# %%
flights.head(1)
# Out:
#    Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0           1  2013      1    1     517.0        2.0     830.0       11.0
#
#   carrier tailnum  flight origin dest  air_time  distance  hour  minute
# 0      UA  N14228    1545    EWR  IAH     227.0      1400   5.0    17.0

# %%
#flights, airports, weather, planes all have no common colomn to be joined on!!!
